# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.4.1'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Machine Learning Project/Cat_or_Dog/dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 6410 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Machine Learning Project/Cat_or_Dog/dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 201/201 [==============================] - 5463s 27s/step - loss: 0.7000 - accuracy: 0.5364 - val_loss: 0.6346 - val_accuracy: 0.6370
# Epoch 2/25
# 201/201 [==============================] - 64s 317ms/step - loss: 0.6297 - accuracy: 0.6453 - val_loss: 0.5950 - val_accuracy: 0.6920
# Epoch 3/25
# 201/201 [==============================] - 64s 318ms/step - loss: 0.5805 - accuracy: 0.6982 - val_loss: 0.5682 - val_accuracy: 0.7050
# Epoch 4/25
# 201/201 [==============================] - 65s 323ms/step - loss: 0.5406 - accuracy: 0.7242 - val_loss: 0.6555 - val_accuracy: 0.6285
# Epoch 5/25
# 201/201 [==============================] - 63s 314ms/step - loss: 0.5431 - accuracy: 0.7189 - val_loss: 0.5191 - val_accuracy: 0.7470
# Epoch 6/25
# 201/201 [==============================] - 64s 317ms/step - loss: 0.4992 - accuracy: 0.7525 - val_loss: 0.4984 - val_accuracy: 0.7715
# Epoch 7/25
# ...

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
one_img = '/content/drive/MyDrive/Machine Learning Project/Cat_or_Dog/single_prediction/cat_or_dog_1.jpg' ## Dog
sec_img = '/content/drive/MyDrive/Machine Learning Project/Cat_or_Dog/single_prediction/cat_or_dog_2.jpg' ## Cat

import numpy as np
from keras.preprocessing import image
test_image = image.load_img(sec_img, target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

# %%
print(prediction)
# Out:
# dog
